# %% [markdown]
# # power_brick — Dual-Rail 12V → 5V / 3.3V Power Supply Brick
#
# 12V barrel/screw input → Buck #1 (TPS54302, 5V@2A) + Buck #2 (TPS54302, 3.3V@1A). Both rails exposed via 2-pin output headers.

# %%
import hw_toolkit as hw
from hw_toolkit.parts import Buck
import pathlib

board = hw.Board("power_brick")
board
# Out:
# Board(project_id='power_brick', subsystems=0, interfaces=0)

# %%
# 12V input connector (2-pin screw/barrel terminal)
# Connector_Generic:Conn_01x02 resolves to a real KiCad symbol.
# Pin_1 = VIN (12V), Pin_2 = GND
j_in = board.module(
    id="j_in",
    category="connector",
    mpn="Conn_01x02",
    package="PinHeader_2.54mm_1x02",
    manufacturer="Generic",
    price_usd=0.10,
)
j_in
# Out:
# Module(pick=SubsystemPick(id='j_in', category='connector', mpn='Conn_01x02', manufacturer='Generic', lcsc=None, package='PinHeader_2.54mm_1x02', datasheet_url='', lib_id='Connector_Generic:Conn_01x02', footprint=None, group=None, qty_per_board=1, price_usd=0.1, stock=0, actuals={}, port_bindings={}), board=Board(project_id='power_brick', subsystems=1, interfaces=0), math=None, notes=[])

# %%
# Buck #1: 12V -> 5V @ 2A
# TPS54302 Vref = 0.8V: Vout = Vref * (1 + Rtop/Rbot)
# For 5V: Rtop/Rbot = (5.0/0.8) - 1 = 5.25
# Rtop=52.3k, Rbot=10k => Vout = 0.8 * (1 + 52.3/10) = 0.8 * 6.23 = 4.984V ≈ 5V
buck_5v = Buck(
    board,
    id="buck_5v",
    mpn="TPS54302",
    package="SOT-23-6",
    vin=12.0,
    vout=5.0,
    l="10uH",
    cin="10uF",
    cout="22uF",
    cboot="100nF",
    rtop="52.3k",
    rbot="10k",
    cap_package="0805",
    res_package="0603",
    ind_package="1210",
)
buck_5v
# Out:
# Module(pick=SubsystemPick(id='buck_5v', category='buck_converter', mpn='TPS54302', manufacturer='', lcsc=None, package='SOT-23-6', datasheet_url='', lib_id='Regulator_Switching:TPS54302', footprint='Package_TO_SOT_SMD:SOT-23-6', group='buck_5v', qty_per_board=1, price_usd=0.0, stock=0, actuals={}, port_bindings={}), board=Board(project_id='power_brick', subsystems=8, interfaces=0), math=None, notes=[])

# %%
# Buck #2: 12V -> 3.3V @ 1A
# For 3.3V: Rtop/Rbot = (3.3/0.8) - 1 = 3.125
# Rtop=31.6k, Rbot=10k => Vout = 0.8 * (1 + 31.6/10) = 0.8 * 4.16 = 3.328V ≈ 3.3V
buck_3v3 = Buck(
    board,
    id="buck_3v3",
    mpn="TPS54302",
    package="SOT-23-6",
    vin=12.0,
    vout=3.3,
    l="10uH",
    cin="10uF",
    cout="22uF",
    cboot="100nF",
    rtop="31.6k",
    rbot="10k",
    cap_package="0805",
    res_package="0603",
    ind_package="1210",
)
buck_3v3
# Out:
# Module(pick=SubsystemPick(id='buck_3v3', category='buck_converter', mpn='TPS54302', manufacturer='', lcsc=None, package='SOT-23-6', datasheet_url='', lib_id='Regulator_Switching:TPS54302', footprint='Package_TO_SOT_SMD:SOT-23-6', group='buck_3v3', qty_per_board=1, price_usd=0.0, stock=0, actuals={}, port_bindings={}), board=Board(project_id='power_brick', subsystems=15, interfaces=0), math=None, notes=[])

# %%
# 5V output header
j_5v = board.module(
    id="j_5v",
    category="connector",
    mpn="Conn_01x02",
    package="PinHeader_2.54mm_1x02",
    manufacturer="Generic",
    price_usd=0.10,
)
j_5v
# Out:
# Module(pick=SubsystemPick(id='j_5v', category='connector', mpn='Conn_01x02', manufacturer='Generic', lcsc=None, package='PinHeader_2.54mm_1x02', datasheet_url='', lib_id='Connector_Generic:Conn_01x02', footprint=None, group=None, qty_per_board=1, price_usd=0.1, stock=0, actuals={}, port_bindings={}), board=Board(project_id='power_brick', subsystems=16, interfaces=0), math=None, notes=[])

# %%
# 3.3V output header
j_3v3 = board.module(
    id="j_3v3",
    category="connector",
    mpn="Conn_01x02",
    package="PinHeader_2.54mm_1x02",
    manufacturer="Generic",
    price_usd=0.10,
)
j_3v3
# Out:
# Module(pick=SubsystemPick(id='j_3v3', category='connector', mpn='Conn_01x02', manufacturer='Generic', lcsc=None, package='PinHeader_2.54mm_1x02', datasheet_url='', lib_id='Connector_Generic:Conn_01x02', footprint=None, group=None, qty_per_board=1, price_usd=0.1, stock=0, actuals={}, port_bindings={}), board=Board(project_id='power_brick', subsystems=17, interfaces=0), math=None, notes=[])

# %%
# --- Net wiring ---
#
# 12V input rail:
# Buck factory creates per-buck VIN nets (buck_5v_vin, buck_3v3_vin).
# We stitch both onto the single 12V node by extending buck_5v_vin
# with the input connector and all of buck_3v3's VIN-side pins.
# (KiCad netlist reconciliation handles the pin appearing in both nets
# by ultimately treating them as one net.)
board.nets["buck_5v_vin"] += (
    "j_in.Pin_1",         # connector 12V positive
    "buck_3v3.VIN",       # 3.3V buck IC VIN pin
    "buck_3v3_cin.1",     # 3.3V buck input cap positive
    "buck_3v3.EN",        # 3.3V buck EN (always-on tie)
)

# GND rail: shared ground net (created by first Buck call)
gnd = board.nets["gnd"]
gnd += "j_in.Pin_2", "j_5v.Pin_2", "j_3v3.Pin_2"

# 5V output: Buck factory created buck_5v_vout with the inductor output
board.nets["buck_5v_vout"] += "j_5v.Pin_1"

# 3.3V output: Buck factory created buck_3v3_vout
board.nets["buck_3v3_vout"] += "j_3v3.Pin_1"

print("12V rail:", board.nets["buck_5v_vin"])
print("GND rail:", board.nets["gnd"])
print("5V rail:", board.nets["buck_5v_vout"])
print("3.3V rail:", board.nets["buck_3v3_vout"])
# Out:
# 12V rail: Net(id='buck_5v_vin', type='power', spec='12.0V', members=7)
# GND rail: Net(id='gnd', type='power', spec='0V', members=11)
# 5V rail: Net(id='buck_5v_vout', type='power', spec='5.0V', members=4)
# 3.3V rail: Net(id='buck_3v3_vout', type='power', spec='3.3V', members=4)

# %%
board.summary()
# Out:
# "Board 'power_brick'\n  parts (17):\n    j_in           Conn_01x02                     PinHeader_2.54mm_1x02  $ 0.10\n    buck_5v        TPS54302                       SOT-23-6        $ 0.00\n    buck_5v_cin    C_10uF_0805                    0805            $ 0.02\n    buck_5v_cout   C_22uF_0805                    0805            $ 0.02\n    buck_5v_cboot  C_100nF_0402                   0402            $ 0.02\n    buck_5v_l      L_10uH_1210                    1210            $ 0.05\n    buck_5v_rtop   R_52.3k_0603                   0603            $ 0.01\n    buck_5v_rbot   R_10k_0603                     0603            $ 0.01\n    buck_3v3       TPS54302                       SOT-23-6        $ 0.00\n    buck_3v3_cin   C_10uF_0805                    0805            $ 0.02\n    buck_3v3_cout  C_22uF_0805                    0805            $ 0.02\n    buck_3v3_cboot C_100nF_0402                   0402            $ 0.02\n    buck_3v3_l     L_10uH_1210                    1210            $ 0.05\n    buck_3v3_rtop  R_31.6k_0603                   0603            $ 0.01\n    buck_3v3_rbot  R_10k_0603                     0603            $ 0.01\n    j_5v           Conn_01x02                     PinHeader_2.54mm_1x02  $ 0.10\n    j_3v3          Conn_01x02                     PinHeader_2.54mm_1x02  $ 0.10\n  nets (11):\n    gnd            [power 0V   ]  buck_5v.GND, buck_5v_cin.2, buck_5v_cout.2, buck_5v_rbot.2, buck_3v3.GND, buck_3v3_cin.2, buck_3v3_cout.2, buck_3v3_rbot.2, j_in.Pin_2, j_5v.Pin_2, j_3v3.Pin_2\n    buck_5v_vin    [power 12.0V]  buck_5v.VIN, buck_5v_cin.1, buck_5v.EN, j_in.Pin_1, buck_3v3.VIN, buck_3v3_cin.1, buck_3v3.EN\n    buck_5v_vout   [power 5.0V ]  buck_5v_l.2, buck_5v_cout.1, buck_5v_rtop.1, j_5v.Pin_1\n    buck_5v_sw     [data  analog]  buck_5v.SW, buck_5v_l.1, buck_5v_cboot.2\n    buck_5v_boot   [data  analog]  buck_5v.BOOT, buck_5v_cboot.1\n    buck_5v_fb     [data  analog]  buck_5v.FB, buck_5v_rtop.2, buck_5v_rbot.1\n    buck_3v3_vin   [power 12.0V]  buck_3v3.VIN, buck_3v3_cin.1, buck_3v3.EN\n    buck_3v3_vout  [power 3.3V ]  buck_3v3_l.2, buck_3v3_cout.1, buck_3v3_rtop.1, j_3v3.Pin_1\n    buck_3v3_sw    [data  analog]  buck_3v3.SW, buck_3v3_l.1, buck_3v3_cboot.2\n    buck_3v3_boot  [data  analog]  buck_3v3.BOOT, buck_3v3_cboot.1\n    buck_3v3_fb    [data  analog]  buck_3v3.FB, buck_3v3_rtop.2, buck_3v3_rbot.1"

# %%
# Inline render — see the placed + ELK-routed schematic
board.show()
# Out:
# <div style="display:inline-block;background:#ffffff;padding:8px;border-radius:4px;box-sizing:border-box;"><svg width="287px" height="500px" preserveAspectRatio="xMidYMid meet"
#   xmlns:svg="http://www.w3.org/2000/svg"
#   xmlns="http://www.w3.org/2000/svg"
#   xmlns:xlink="http://www.w3.org/1999/xlink"
#   xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#   version="1.1"
#   viewBox="-2.0000 -2.0000 260.5300 453.5800">
# <title>SVG Image created as power_brick.svg date 2026-06-01T14:52:34 </title>
#   <desc>Image generated by Eeschema-SVG </desc>
# <g style="fill:#000000; fill-opacity:1.0000;stroke:#000000; stroke-opacity:1.0000;
# stroke-linecap:round; stroke-linejoin:round;"
#  transform="translate(0 0) scale(1 1)">
# <path style="fill:none;
# stroke:#840000; stroke-width:0.5080; stroke-opacity:1;
# stroke-linecap:round; stroke-linejoin:round;fill:none"
# d="M 207.5180,406.9080
# 211.5820,406.9080
# " />
# <path style="fill:none;
# stroke:#840000; stroke-width:0.5080; stroke-opacity:1;
# stroke-linecap:round; stroke-linejoin:round;fill:none"
# d="M 207.5180,408.4320
# 211.5820,408.4320
# " />
# </g>
# L219.1256 405.2257
# " />
# <path d="M219.1256 405.2257
# L219.0651 405.4676
# " />
# <path d="M219.0651 405.4676
# L219.0046 405.5886
# " />
# <path d="M219.0046 405.5886
# L218.9441 405.6491
# " />
# <path d="M218.9441 405.6491
# L218.8232 405.7095
# " />
# <path d="M218.8232 405.7095
# L218.7022 405.7095
# " />
# <path d="M218.7022 405.7095
# L218.5813 405.6491
# " />
# <path d="M218.5813 405.6491
# L218.5208 405.5886
# " />
# <path d="M218.5208 405.5886
# L218.4603 405.4676
# " />
# <path d="M218.4603 405.4676
# L218.3999 405.2257
# " />
# <path d="M218.3999 405.2257
# L218.3999 404.9233
# " />
# <path d="M218.3999 404.9233
# L218.4603 404.6814
# " />
# <path d="M218.4603 404.6814
# L218.5208 404.5605
# " />
# <path d="M218.5208 404.5605
# L218.5813 404.5000
# " />
# <path d="M218.5813 404.5000
# L218.7022 404.4395
# " />
# <path d="M219.8513 404.9838
# L219.7303 404.9233
# " />
# <path d="M219.7303 404.9233
# L219.6698 404.8629
# " />
# <path d="M219.6698 404.8629
# L219.6094 404.7419
# " />
# <path d="M219.6094 404.7419
# L219.6094 404.6814
# " />
# <path d="M219.6094 404.6814
# L219.6698 404.5605
# " />
# <path d="M219.6698 404.5605
# L219.7303 404.5000
# " />
# <path d="M219.7303 404.5000
# L219.8513 404.4395
# " />
# <path d="M219.8513 404.4395
# L220.0932 404.4395
# " />
# <path d="M220.0932 404.4395
# L220.2141 404.5000
# " />
# <path d="M220.2141 404.5000
# L220.2746 404.5605
# " />
# <path d="M220.2746 404.5605
# L220.3351 404.6814
# " />
# <path d="M220.3351 404.6814
# L220.3351 404.7419
# " />
# <path d="M220.3351 404.7419
# L220.2746 404.8629
# " />
# <path d="M220.2746 404.8629
# L220.2141 404.9233
# " />
# <path d="M220.2141 404.9233
# L220.0932 404.9838
# " />
# <path d="M220.0932 404.9838
# L219.

# %%
# PCB: footprints placed + ratsnest airwires (copper not routed yet).
# Parts with no mapped footprint are listed in res.skipped.
res = board.write_pcb()
print("placed:", res.placed, "| skipped:", res.skipped)
board.show_pcb()
# Out:
# placed: ('U1', 'U2', 'U3', 'U4', 'U5', 'U6', 'U7', 'U8', 'U9', 'U10', 'U11', 'U12', 'U13', 'U14') | skipped: {'J1': 'no footprint assigned', 'J2': 'no footprint assigned', 'J3': 'no footprint assigned'}
# <div style="display:inline-block;background:#ffffff;padding:8px;border-radius:4px;box-sizing:border-box;"><svg width="900px" height="473px" preserveAspectRatio="xMidYMid meet"
#   xmlns:svg="http://www.w3.org/2000/svg"
#   xmlns="http://www.w3.org/2000/svg"
#   xmlns:xlink="http://www.w3.org/1999/xlink"
#   xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#   version="1.1"
#   viewBox="-7.7440 -2.0000 85.2370 44.7500">
# <title>SVG Image created as power_brick.pcb.svg date 2026-06-01T14:53:12 </title>
#   <desc>Image generated by PCBNEW </desc>
# <g style="fill:#000000; fill-opacity:1.0000;stroke:#000000; stroke-opacity:1.0000;
# stroke-linecap:round; stroke-linejoin:round;"
#  transform="translate(0 0) scale(1 1)">
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 5.3370,5.8500
# 5.3484,5.7926
# 5.3809,5.7439
# 5.4296,5.7114
# 5.4870,5.7000
# 6.5120,5.7000
# 6.5694,5.7114
# 6.6181,5.7439
# 6.6506,5.7926
# 6.6620,5.8500
# 6.6620,6.1500
# 6.6506,6.2074
# 6.6181,6.2561
# 6.5694,6.2886
# 6.5120,6.3000
# 5.4870,6.3000
# 5.4296,6.2886
# 5.3809,6.2561
# 5.3484,6.2074
# 5.3370,6.1500
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 5.3370,6.8000
# 5.3484,6.7426
# 5.3809,6.6939
# 5.4296,6.6614
# 5.4870,6.6500
# 6.5120,6.6500
# 6.5694,6.6614
# 6.6181,6.6939
# 6.6506,6.7426
# 6.6620,6.8000
# 6.6620,7.1000
# 6.6506,7.1574
# 6.6181,7.2061
# 6.5694,7.2386
# 6.5120,7.2500
# 5.4870,7.2500
# 5.4296,7.2386
# 5.3809,7.2061
# 5.3484,7.1574
# 5.3370,7.1000
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 5.3370,7.7500
# 5.3484,7.6926
# 5.3809,7.6439
# 5.4296,7.6114
# 5.4870,7.6000
# 6.5120,7.6000
# 6.5694,7.6114
# 6.6181,7.6439
# 6.6506,7.6926
# 6.6620,7.7500
# 6.6620,8.0500
# 6.6506,8.1074
# 6.6181,8.1561
# 6.5694,8.1886
# 6.5120,8.2000
# 5.4870,8.2000
# 5.4296,8.1886
# 5.3809,8.1561
# 5.3484,8.1074
# 5.3370,8.0500
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 7.6120,7.7500
# 7.6234,7.6926
# 7.6559,7.6439
# 7.7046,7.6114
# 7.7620,7.6000
# 8.7870,7.6000
# 8.8444,7.6114
# 8.8931,7.6439
# 8.9256,7.6926
# 8.9370,7.7500
# 8.9370,8.0500
# 8.9256,8.1074
# 8.8931,8.1561
# 8.8444,8.1886
# 8.7870,8.2000
# 7.7620,8.2000
# 7.7046,8.1886
# 7.6559,8.1561
# 7.6234,8.1074
# 7.6120,8.0500
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 7.6120,6.8000
# 7.6234,6.7426
# 7.6559,6.6939
# 7.7046,6.6614
# 7.7620,6.6500
# 8.7870,6.6500
# 8.8444,6.6614
# 8.8931,6.6939
# 8.9256,6.7426
# 8.9370,6.8000
# 8.9370,7.1000
# 8.9256,7.1574
# 8.8931,7.2061
# 8.8444,7.2386
# 8.7870,7.2500
# 7.7620,7.2500
# 7.7046,7.2386
# 7.6559,7.2061
# 7.6234,7.1574
# 7.6120,7.1000
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 7.6120,5.8500
# 7.6234,5.7926
# 7.6559,5.7439
# 7.7046,5.7114
# 7.7620,5.7000
# 8.7870,5.7000
# 8.8444,5.7114
# 8.8931,5.7439
# 8.9256,5.7926
# 8.9370,5.8500
# 8.9370,6.1500
# 8.9256,6.2074
# 8.8931,6.2561
# 8.8444,6.2886
# 8.7870,6.3000
# 7.7620,6.3000
# 7.7046,6.2886
# 7.6559,6.2561
# 7.6234,6.2074
# 7.6120,6.1500
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 19.9620,6.4750
# 19.9810,6.3793
# 20.0352,6.2982
# 20.1163,6.2440
# 20.2120,6.2250
# 20.7120,6.2250
# 20.8077,6.2440
# 20.8888,6.2982
# 20.9430,6.3793
# 20.9620,6.4750
# 20.9620,7.4250
# 20.9430,7.5207
# 20.8888,7.6018
# 20.8077,7.6560
# 20.7120,7.6750
# 20.2120,7.6750
# 20.1163,7.6560
# 20.0352,7.6018
# 19.9810,7.5207
# 19.9620,7.4250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 21.8620,6.4750
# 21.8810,6.3793
# 21.9352,6.2982
# 22.0163,6.2440
# 22.1120,6.2250
# 22.6120,6.2250
# 22.7077,6.2440
# 22.7888,6.2982
# 22.8430,6.3793
# 22.8620,6.4750
# 22.8620,7.4250
# 22.8430,7.5207
# 22.7888,7.6018
# 22.7077,7.6560
# 22.6120,7.6750
# 22.1120,7.6750
# 22.0163,7.6560
# 21.9352,7.6018
# 21.8810,7.5207
# 21.8620,7.4250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 33.8620,6.4750
# 33.8810,6.3793
# 33.9352,6.2982
# 34.0163,6.2440
# 34.1120,6.2250
# 34.6120,6.2250
# 34.7077,6.2440
# 34.7888,6.2982
# 34.8430,6.3793
# 34.8620,6.4750
# 34.8620,7.4250
# 34.8430,7.5207
# 34.7888,7.6018
# 34.7077,7.6560
# 34.6120,7.6750
# 34.1120,7.6750
# 34.0163,7.6560
# 33.9352,7.6018
# 33.8810,7.5207
# 33.8620,7.4250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 35.7620,6.4750
# 35.7810,6.3793
# 35.8352,6.2982
# 35.9163,6.2440
# 36.0120,6.2250
# 36.5120,6.2250
# 36.6077,6.2440
# 36.6888,6.2982
# 36.7430,6.3793
# 36.7620,6.4750
# 36.7620,7.4250
# 36.7430,7.5207
# 36.6888,7.6018
# 36.6077,7.6560
# 36.5120,7.6750
# 36.0120,7.6750
# 35.9163,7.6560
# 35.8352,7.6018
# 35.7810,7.5207
# 35.7620,7.4250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 48.4520,6.7800
# 48.4627,6.7264
# 48.4930,6.6810
# 48.5384,6.6507
# 48.5920,6.6400
# 48.8720,6.6400
# 48.9256,6.6507
# 48.9710,6.6810
# 49.0013,6.7264
# 49.0120,6.7800
# 49.0120,7.1200
# 49.0013,7.1736
# 48.9710,7.2190
# 48.9256,7.2493
# 48.8720,7.2600
# 48.5920,7.2600
# 48.5384,7.2493
# 48.4930,7.2190
# 48.4627,7.1736
# 48.4520,7.1200
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 49.4120,6.7800
# 49.4227,6.7264
# 49.4530,6.6810
# 49.4984,6.6507
# 49.5520,6.6400
# 49.8320,6.6400
# 49.8856,6.6507
# 49.9310,6.6810
# 49.9613,6.7264
# 49.9720,6.7800
# 49.9720,7.1200
# 49.9613,7.1736
# 49.9310,7.2190
# 49.8856,7.2493
# 49.8320,7.2600
# 49.5520,7.2600
# 49.4984,7.2493
# 49.4530,7.2190
# 49.4227,7.1736
# 49.4120,7.1200
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 60.1470,5.8750
# 60.1660,5.7793
# 60.2202,5.6982
# 60.3013,5.6440
# 60.3970,5.6250
# 61.1470,5.6250
# 61.2427,5.6440
# 61.3238,5.6982
# 61.3780,5.7793
# 61.3970,5.8750
# 61.3970,8.0250
# 61.3780,8.1207
# 61.3238,8.2018
# 61.2427,8.2560
# 61.1470,8.2750
# 60.3970,8.2750
# 60.3013,8.2560
# 60.2202,8.2018
# 60.1660,8.1207
# 60.1470,8.0250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 62.9470,5.8750
# 62.9660,5.7793
# 63.0202,5.6982
# 63.1013,5.6440
# 63.1970,5.6250
# 63.9470,5.6250
# 64.0427,5.6440
# 64.1238,5.6982
# 64.1780,5.7793
# 64.1970,5.8750
# 64.1970,8.0250
# 64.1780,8.1207
# 64.1238,8.2018
# 64.0427,8.2560
# 63.9470,8.2750
# 63.1970,8.2750
# 63.1013,8.2560
# 63.0202,8.2018
# 62.9660,8.1207
# 62.9470,8.0250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 5.9120,20.5750
# 5.9272,20.4985
# 5.9706,20.4336
# 6.0355,20.3902
# 6.1120,20.3750
# 6.5120,20.3750
# 6.5885,20.3902
# 6.6534,20.4336
# 6.6968,20.4985
# 6.7120,20.5750
# 6.7120,21.1250
# 6.6968,21.2015
# 6.6534,21.2664
# 6.5885,21.3098
# 6.5120,21.3250
# 6.1120,21.3250
# 6.0355,21.3098
# 5.9706,21.2664
# 5.9272,21.2015
# 5.9120,21.1250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 7.5620,20.5750
# 7.5772,20.4985
# 7.6206,20.4336
# 7.6855,20.3902
# 7.7620,20.3750
# 8.1620,20.3750
# 8.2385,20.3902
# 8.3034,20.4336
# 8.3468,20.4985
# 8.3620,20.5750
# 8.3620,21.1250
# 8.3468,21.2015
# 8.3034,21.2664
# 8.2385,21.3098
# 8.1620,21.3250
# 7.7620,21.3250
# 7.6855,21.3098
# 7.6206,21.2664
# 7.5772,21.2015
# 7.5620,21.1250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 19.5620,20.5750
# 19.5772,20.4985
# 19.6206,20.4336
# 19.6855,20.3902
# 19.7620,20.3750
# 20.1620,20.3750
# 20.2385,20.3902
# 20.3034,20.4336
# 20.3468,20.4985
# 20.3620,20.5750
# 20.3620,21.1250
# 20.3468,21.2015
# 20.3034,21.2664
# 20.2385,21.3098
# 20.1620,21.3250
# 19.7620,21.3250
# 19.6855,21.3098
# 19.6206,21.2664
# 19.5772,21.2015
# 19.5620,21.1250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 21.2120,20.5750
# 21.2272,20.4985
# 21.2706,20.4336
# 21.3355,20.3902
# 21.4120,20.3750
# 21.8120,20.3750
# 21.8885,20.3902
# 21.9534,20.4336
# 21.9968,20.4985
# 22.0120,20.5750
# 22.0120,21.1250
# 21.9968,21.2015
# 21.9534,21.2664
# 21.8885,21.3098
# 21.8120,21.3250
# 21.4120,21.3250
# 21.3355,21.3098
# 21.2706,21.2664
# 21.2272,21.2015
# 21.2120,21.1250
# Z" />
# <path style="fill:#C83434; fill-opacity:1.0000; stroke:none;fill-rule:evenodd;"
# d="M 32.6370,19.7500
# 32.6484,19.6926
# 32.6809,19.6439
# 32.7296,19.6114
# 32.7870,19.6000
# 33.8120,19.6000
# 33.8694,19.6114
# 33.9181,19.6439
# 33.9506,19.6926
# 33.9620,19.7500
# 33.9620,20.0500
# 33.9506,20.1074
# 33.9181,20.1561
# 33.8694,20.1886

# %%
# ERC — all parts (TPS54302, Device:R/C/L, Connector_Generic:Conn_01x02)
# resolve to real KiCad symbols, so gate on ERC_REAL_SYMBOL_CODES (tighter set).
board.check_erc(expected_codes=hw.ERC_REAL_SYMBOL_CODES)

# %%
# Export — absolute path per AGENT_GUIDE §7
out = pathlib.Path("/Users/juanantonioluera/ws/hw-toolkit/docs/projects/power_brick/power_brick.zip")
board.export_kicad(out, unzip=True, expected_codes=hw.ERC_REAL_SYMBOL_CODES)
print("Exported:", out)
assert out.exists(), "zip not created!"
print("ZIP size:", out.stat().st_size, "bytes")
# Out:
# Exported: /Users/juanantonioluera/ws/hw-toolkit/docs/projects/power_brick/power_brick.zip
# ZIP size: 43455 bytes
