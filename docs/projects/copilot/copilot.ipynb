# %% [markdown]
# # hw_toolkit copilot
#
# **Claude Code is the brain; this notebook is the canvas.**
#
# 1. Select the kernel (top-right) → the project venv (`python3` / `hw-toolkit-venv`).
# 2. Run the setup cell below once. `board.live()` opens a **self-refreshing
#    schematic pane** — the KiCad version of openscad-studio's live viewer.
# 3. Talk to Claude Code in chat. It writes `hw_toolkit` code in *this* kernel
#    (via the IDE bridge), and every `board.write_kicad()` repaints the live
#    pane above by itself — no manual re-render.
#
# The `board` object is shared: what Claude edits is what you see, live.

# %%
import hw_toolkit as hw

board = hw.Board("copilot")

# Studio loop: this pane re-renders itself on every write_kicad() — like
# openscad-studio watching a .scad file. Run once; leave it.
view = board.live()
view
