# %% [markdown]
# # hw_toolkit copilot
#
# **Claude Code is the brain; this notebook is the canvas.**
#
# 1. Select the kernel (top-right) → the project venv (`python3` / `hw-toolkit-venv`).
# 2. Run the setup cell below once.
# 3. Talk to Claude Code in chat. It runs `hw_toolkit` code in *this* kernel
#    (via the IDE bridge), mutating the live `board` and rendering the
#    schematic + PCB inline right here.
#
# The `board` object is shared: what Claude edits is what you see.

# %%
import hw_toolkit as hw
from hw_toolkit.parts import Buck

board = hw.Board("copilot")
board
